# %%
import networkx as nx
import json
from tqdm import tqdm
import numpy as np

# %%
projection = 'simple_weight'

# %%
G = nx.read_gpickle(f'../data/projections/pickle_format/{projection}.pickle')

# %%
with open('../data/transformed/metadata.json') as infile:
    metadata = json.load(infile)

# %%
def single_repo_recommend(G, n):
    return {node: [G.nodes[el[1]]['metadata'] for el in sorted([edge for edge in G.edges(node, data=True)] , key=lambda x:x[-1]['weight'], reverse=True)][:n] for node in G.nodes()}

# %%
path = f'../recommendations/{projection}'
n = 5

with open(path + 'single_recommend{n}.json', 'w') as outfile:
    json.dump(single_repo_recommend(G, n=5), outfile)

# %%
# get sorted neighbors of node
sorted(G['r7'].items(), key=lambda x:x[1]['weight'], reverse=True)
# Out:
# [('r1030', {'weight': 3}),
#  ('r1606', {'weight': 2}),
#  ('r1348', {'weight': 2}),
#  ('r1102', {'weight': 2}),
#  ('r4364', {'weight': 2}),
#  ('r5000', {'weight': 2}),
#  ('r654', {'weight': 2}),
#  ('r949', {'weight': 2}),
#  ('r1173', {'weight': 2}),
#  ('r749', {'weight': 2}),
#  ('r38423', {'weight': 2}),
#  ('r518', {'weight': 2}),
#  ('r162', {'weight': 2}),
#  ('r3213', {'weight': 2}),
#  ('r1267', {'weight': 2}),
#  ('r302', {'weight': 2}),
#  ('r1200', {'weight': 2}),
#  ('r146', {'weight': 2}),
#  ('r2140', {'weight': 2}),
#  ('r354', {'weight': 2}),
#  ('r117408', {'weight': 1}),
#  ('r77960', {'weight': 1}),
#  ('r29905', {'weight': 1}),
#  ('r1927', {'weight': 1}),
#  ('r76370', {'weight': 1}),
#  ('r28020', {'weight': 1}),
#  ('r56527', {'weight': 1}),
#  ('r11825', {'weight': 1}),
#  ('r58259', {'weight': 1}),
#  ('r25749', {'weight': 1}),
#  ('r5495', {'weight': 1}),
#  ('r58037', {'weight': 1}),
#  ('r13229', {'weight': 1}),
#  ('r28025', {'weight': 1}),
# ...

# %%
metadata['r1']
# Out:
# {'repo_name': 'richardc/perl-number-compare',
#  'creation_date': '2009-02-26',
#  'forked_from_id': None,
#  'languages': [['Perl', '3712']]}

# %%
def naive_recommend(G, metadata, n=5, filepath='.', name='untitled'):
    recommendations = {}
    for node in tqdm(G.nodes()):
        sorted_neighbors = sorted(G[node].items(), key=lambda x:x[1]['weight'], reverse=True)
        repo_names = [metadata[r]['repo_name'] for r, _ in sorted_neighbors]
        recommendations[metadata[node]['repo_name']] = repo_names
    
    return recommendations
        
recommend = naive_recommend(G, metadata)
# Out:
# 100%|█████████████████████████████████████████████████████████| 120867/120867 [01:28<00:00, 1361.81it/s]

# %%
recommend['rails/rails']
# Out:
# ['technoweenie/restful-authentication',
#  'mislav/will_paginate',
#  'dchelimsky/rspec',
#  'thoughtbot/paperclip',
#  'binarylogic/authlogic',
#  'aslakhellesoy/cucumber',
#  'technoweenie/attachment_fu',
#  'dchelimsky/rspec-rails',
#  'jamis/capistrano',
#  'joshuaclayton/blueprint-css',
#  'fudgestudios/bort',
#  'brynary/webrat',
#  'FooBarWidget/passenger',
#  'drnic/ruby-on-rails-tmbundle',
#  'madrobby/scriptaculous',
#  'nex3/haml',
#  'thoughtbot/shoulda',
#  'Caged/gitnub',
#  'javan/whenever',
#  'wycats/merb-core',
#  'thoughtbot/factory_girl',
#  'tobi/delayed_job',
#  'chriseppstein/compass',
#  'sstephenson/prototype',
#  'rubyist/aasm',
#  'Shopify/active_merchant',
#  'insoshi/insoshi',
#  'freelancing-god/thinking-sphinx',
#  'sandal/prawn',
#  'nkallen/cache-money',
#  'mojombo/jekyll',
#  'binarylogic/searchlogic',
#  'jnunemaker/httparty',
#  'tenderlove/nokogiri',
#  'railsdog/spree',
#  'pieter/gitx',
#  'thoughtbot/clearance',
# ...

# %%
[metadata[r]['repo_name'] for r, _ in sorted(dict(G.degree()).items(), key=lambda x:x[1], reverse=True)[:50]]
# Out:
# ['rails/rails',
#  'technoweenie/restful-authentication',
#  'binarylogic/authlogic',
#  'mislav/will_paginate',
#  'aslakhellesoy/cucumber',
#  'joshuaclayton/blueprint-css',
#  'thoughtbot/paperclip',
#  'brynary/webrat',
#  'mojombo/jekyll',
#  'dchelimsky/rspec',
#  'chriseppstein/compass',
#  'javan/whenever',
#  'tobi/delayed_job',
#  'Caged/gitnub',
#  'fudgestudios/bort',
#  'ezmobius/nanite',
#  'defunkt/github-gem',
#  'technoweenie/attachment_fu',
#  'pilu/web-app-theme',
#  'jamis/capistrano',
#  'jnunemaker/httparty',
#  'tenderlove/nokogiri',
#  'foca/integrity',
#  'nkallen/cache-money',
#  'pieter/gitx',
#  'FooBarWidget/passenger',
#  'nex3/haml',
#  'thoughtbot/shoulda',
#  'bmizerany/sinatra',
#  'mojombo/god',
#  'mojombo/grit',
#  'crafterm/sprinkle',
#  'thoughtbot/factory_girl',
#  'Shopify/active_merchant',
#  'sandal/prawn',
#  'notahat/machinist',
#  'dchelimsky/rspec-rails',
#  'freelancing-god/thinking-sphinx',
#  'drnic/ruby-on-rails-tmbundle',
# ...

# %%
def find_all_python_repos(metadata):
    python_repos = []
    for val in tqdm(metadata.values()):
        if 'languages' in list(val):
            langs = np.array(val['languages'])
            if (langs == 'Python').any():
                python_repos.append(val['repo_name'])
            
    return python_repos

python_repos = find_all_python_repos(metadata)
# Out:
# 100%|███████████████████████████████████████████████████████| 120867/120867 [00:00<00:00, 196295.57it/s]

# %%
python_repos
# Out:
# ['chrisdrackett/django-typogrify',
#  'ellisonbg/hermes2d',
#  'sorl/django-recipes',
#  'DocSavage/bloog',
#  'svenfuchs/adva_cms',
#  't-lo/ahkera',
#  'svetlyak40wt/django-tagging-ng',
#  'iballok/earley',
#  'dreiss/thrift',
#  'wlach/halifax-transit-feed',
#  'mintchaos/django_inlines',
#  'candersonmiller/anderson-miller---itp--glart',
#  'certik/pydy',
#  'robhudson/django-debug-toolbar',
#  'nigelkersten/puppet',
#  'dinoboff/github-tools',
#  'gsancho/pymenthon.rdb',
#  'rectalogic/xbmc-fancast-plugin',
#  'tristan/project-euler-code',
#  'william-os4y/fapws2',
#  'sriramk/smoke',
#  'bo198214/hyperops',
#  'inky/see',
#  'FooBarWidget/passenger',
#  'jleahy/oxstu',
#  'fen/thebc',
#  'manniche/timereg',
#  'bradleywright/mnml',
#  'orestis/pysmell',
#  'opscode/chef',
#  'rndmcnlly/cv',
#  'marshall/titanium',
#  'henriklied/django-twitter-oauth',
#  'SnippyHolloW/pruning_phrase_table',
#  'inet-framework/inet',
#  'lethain/django-userskins',
#  'jmalonzo/pywebkitgtk',
# ...
